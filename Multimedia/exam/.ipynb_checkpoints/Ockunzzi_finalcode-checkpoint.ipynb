# %% [markdown]
# ### Sam Ockunzzi
# 2697186

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np
from scipy import ndimage
import sys,os
import math
# %config Completer.use_jedi = False

# %%
img_bin = np.load('CIS_465/FE_Data.npy')

# %%
def display_img(img, gray=False):
    '''
    img = input image or image like array
    gray = bool for displaying a grayscale image
    '''
    plt.axis('off')
    if(gray):
        plt.imshow(img, cmap='gray', vmin=0, vmax=255)
        plt.show()
    else:
        plt.imshow(img)
        plt.show()

# %%
img_bin.shape
# Out:
# (2, 192, 168)

# %%
display_img(cv2.cvtColor(img_bin[0], cv2.COLOR_BGR2RGB))

# %%
display_img(cv2.cvtColor(img_bin[1], cv2.COLOR_BGR2RGB))

# %%
sqrt2=math.sqrt(2)

# %%
k1=[
    [1,sqrt2,1],
    [0,0,0],
    [-1,-sqrt2,-1]
]

k2=[
    [1,0,-1],
    [sqrt2,0,-sqrt2],
    [1,0,-1]
]

k3=[
    [0,-1,sqrt2],
    [1,0,-1],
    [-sqrt2,1,0]
]

k4=[
    [sqrt2,-1,0],
    [-1,0,1],
    [0,1,-sqrt2]
]

k5=[
    [0,1,0],
    [-1,0,-1],
    [0,1,0]
]

k6=[
    [-1,0,1],
    [0,0,0],
    [1,0,-1]
]
k7=[
    [1,-2,1],
    [-2,4,-2],
    [1,-2,1]
]
k8=[
    [-2,1,-2],
    [1,4,1],
    [-2,1,-2]
]
k9=[
    [1,1,1],
    [1,1,1],
    [1,1,1]
]
